% %% [markdown]
% This is documentation of the data processing used to analyse stuff
% using equation
%
% $$ a=b \frac{c}{c^f} $$

% %%
a=1:100;
b=rand(100,100);

figure
clf
imagesc(b)
colorbar

% %%
60*62
% Out:
% ans =
%
%         3720
